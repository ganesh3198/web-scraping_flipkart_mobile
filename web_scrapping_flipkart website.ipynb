# %%
# import libraries 

from bs4 import BeautifulSoup
import requests
url='https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %%
#url = 'https://www.amazon.in/s?i=luggage&bbn=2917431031&rh=n%3A2454169031%2Cn%3A2917431031%2Cn%3A2917441031%2Cp_n_feature_nineteen_browse-bin%3A11301361031&s=popularity-rank&dc&ds=v1%3A9YSM5ItP5QXQkZM7qlvIrafLLfnhwwlbcTOqVWHkuvs&pf_rd_i=13714205031&pf_rd_i=13714205031&pf_rd_i=13714205031&pf_rd_i=13714205031%2C13714205031&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_m=A1VBAL9TL5WCBF%2CA1VBAL9TL5WCBF&pf_rd_p=066549c2-4eb2-48e7-8e7e-93a921747fcc&pf_rd_p=34016f26-bc74-47e7-b5d3-2f255120e73f%2C7029cbbc-69c0-45de-b15e-dbfa02a697ee&pf_rd_p=35f70922-33c2-469b-979e-311c4cef0b5a&pf_rd_p=837154a9-c149-4cdb-8e10-7df8420005d5&pf_rd_r=A6C75EBV9D7BP2PA37XW&pf_rd_r=A7021W2WGA0YXR4E96X0&pf_rd_r=DX3GW10ZKN05XRNVTRNY%2CN6WFGF92EP2K470NMNJE&pf_rd_r=J2VQQJQ19QN1S1D2AA2K&pf_rd_s=merchandised-search-1&pf_rd_s=merchandised-search-11&pf_rd_s=merchandised-search-6%2Cmerchandised-search-8&pf_rd_s=merchandised-search-7&qid=1689189983&rnid=2917431031&ref=sr_nr_n_2'

#headers= ({'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'}) #add your user agentpage = requests.get(url)
# check status code for response received 
# success code - 200

# %%
for i in range(1,7):
    url="https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"+str(i)
    r = requests.get(url)
    np = box.find("a",class_ ="_1LKTO3").get("href")
    cnp = https://www.flipkart.com/+np
    url=cnp
    soup = BeautifulSoup(r.text, 'lxml') 
    box = soup.find("div",class_ = "_1YokD2 _3Mn1Gg")
    products = []
    prices = []
    ratings = []
    description = []
    
    product = box.find_all("div",class_ = "_4rR01T")
    #print(content)
    #print(len(content))
    for i in product:
        name=i.text
        products.append(name)
   

    price = box.find_all("div",class_ = "_30jeq3 _1_WHN1")
    #print(price)
    #print(len(price))
    for i in price:
        no=i.text
        prices.append(no)

    
    desc = box.find_all("ul",class_ = "_1xgFaf")
    #print(desc)
    #print(len(desc))
    for i in desc:
        de=i.text
        description.append(de)


    review = box.find_all("div",class_ = "_3LWZlK")
    #print(review)
    #print(len(review))
    for i in review:
        rs=i.text
        ratings.append(rs)

# %%
import pandas as pd
df=pd.DataFrame({"product_name":products,"prices":prices,"description":description,"review": ratings})

# %%
df
# Out:
#                                          product_name   prices  \
# 0                  REDMI Note 12 (Lunar Black, 64 GB)  ₹11,999
# 1                    REDMI Note 12 (Ice Blue, 128 GB)  ₹13,999
# 2            OnePlus 11R 5G (Galactic Silver, 256 GB)  ₹43,421
# 3               Nothing Phone (2) (Dark Grey, 512 GB)  ₹49,999
# 4                OnePlus 11R 5G (Sonic Black, 256 GB)  ₹43,831
# 5           SAMSUNG Galaxy Z Flip3 5G (Cream, 128 GB)  ₹49,999
# 6                   Nothing Phone (2) (White, 512 GB)  ₹49,999
# 7                 REDMI Note 12 (Sunrise Gold, 64 GB)  ₹11,999
# 8              Xiaomi 12 Pro 5G (Opera Mauve, 256 GB)  ₹49,999
# 9   SAMSUNG Galaxy Z Flip3 5G (Phantom Black, 128 GB)  ₹49,999
# 10                REDMI Note 12 (Lunar Black, 128 GB)  ₹13,999
# 11               REDMI Note 12 (Sunrise Gold, 128 GB)  ₹13,999
# 12              Xiaomi 12 Pro 5G (Noir Black, 256 GB)  ₹49,999
# 13      SAMSUNG Galaxy S20 FE 5G (Cloud Navy, 128 GB)  ₹28,900
# ...
